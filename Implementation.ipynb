# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
from sklearn.compose import make_column_transformer 
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
df=pd.read_csv("data.csv")

# %%
df.head(50)
# Out:
#     month  year       brandname        productname               name   weight
# 0       8  2020   Mahavir Steel              Angle          25*25*3mm     11.0
# 1       8  2020      TATA Pipes     G.I. Pipe(Mtr)    100_5.4_C Class   1480.0
# 2       8  2020    G.D.MALHOTRA               Beam           100*50 L   1707.3
# 3       8  2020   Mahavir Steel            Channel         75*40 -1.7     34.2
# 4       8  2020      Polish Bar         Polish Bar             R 16mm      9.5
# 5       8  2020      TATA Pipes  Round_Pipes (Mtr)  150_C CLASS_5.4mm   5836.2
# 6       8  2020      Rajuri TMT                TMT              06 MM    195.7
# 7       8  2020    VIZAG / SAIL            Channel         200*75 STD   8909.3
# 8       8  2020   AM/NS (Essar)             SHEET       3mm*1020*3050    146.0
# 9       8  2020    G.D.MALHOTRA            Channel              70*35   4160.0
# 10      8  2020  TATA Structura        Square_Pipe   25*25*1.6_YST210   2937.2
# 11      8  2020      TATA Pipes  Round_Pipes (Mtr)  125_C CLASS_5.4mm   3329.4
# 12      8  2020    VIZAG / SAIL            Channel         100*50 STD  45582.9
# 13      8  2020    VIZAG / SAIL            Channel         125*65 STD   9889.2
# 14      8  2020    VIZAG / SAIL              Angle          90*90*8mm   1404.0
# 15      8  2020    VIZAG / SAIL               Beam         150*75 STD    180.0
# 16      8  2020   AM/NS (Essar)              Plate      8mm*1250*2500   1666.0
# 17      8  2020   Mahavir Steel               Flat             300*10    600.5
# 18      8  2020  TATA Structura        Square_Pipe   40*40*2.0_YST210   2289.0
# 19      8  2020         Rolling          Round_Bar               12mm    555.4
# 20      8  2020         Rolling               Flat               25*5    696.0
# 21      8  2020  TATA Structura        Square_Pipe   20*20*1.2_YST210    724.5
# 22      8  2020  TATA Structura        Square_Pipe   20*20*1.6_YST210   1873.8
# 23      8  2020  TATA Structura        Square_Pipe   50*50*1.6_YST210   5145.0
# 24      8  2020         Rolling               Flat               25*6    187.2
# 25      8  2020   As Per IS2062               Flat              200*8    176.4
# 26      8  2020   AM/NS (Essar)              Plate      6mm*1250*6300    206.3
# 27      8  2020   AM/NS (Essar)              Plate     12mm*1250*6300    558.8
# 28      8  2020   AM/NS (Essar)             SHEET    3.15mm*1250*2500   1716.0
# 29      8  2020    G.D.MALHOTRA            Channel         75*40 -1.7  10082.6
# 30      8  2020         Rolling         Square_Bar              10*10      4.7
# 31      8  2020   As Per IS2062               Flat             100*12    225.6
# 32      8  2020   AM/NS (Essar)             SHEET       2mm*1250*2500    750.0
# 33      8  2020    G.D.MALHOTRA              Angle          40*40*5mm   1134.0
# 34      8  2020  TATA Structura        Square_Pipe   80*40*2.9_YST210     61.9
# 35      8  2020   AM/NS (Essar)              Plate      8mm*1500*6300   7500.0
# 36      8  2020   As Per IS2062               Flat              50*16     37.8
# 37      8  2020   AM/NS (Essar)              Plate      4mm*1250*2500   2400.0
# 38      8  2020    G.D.MALHOTRA               Flat               40*5   1507.2
# 39      8  2020    G.D.MALHOTRA               Flat               32*6      9.0
# 40      8  2020   As Per IS2062               Flat               40*8    105.0
# 41      8  2020   AM/NS (Essar)              Plate      4mm*1500*6300   2900.0
# 42      8  2020   AM/NS (Essar)              Plate      5mm*1500*6300   4500.0
# 43      8  2020   AM/NS (Essar)              Plate      5mm*1250*2500    125.0
# 44      8  2020   AM/NS (Essar)              Plate      5mm*1250*6300   2205.0
# 45      8  2020   AM/NS (Essar)              Plate     12mm*2000*6300    942.0
# 46      8  2020    G.D.MALHOTRA            Channel         100*50 MED   2296.8
# 47      8  2020    G.D.MALHOTRA            Channel         75*40 -1.9   1716.0
# 48      8  2020   Mahavir Steel               Flat             300*12   1068.8
# 49      8  2020    G.D.MALHOTRA               Flat              75*12     42.6

# %%
df.columns
# Out:
# Index(['month', 'year', 'brandname', 'productname', 'name', 'weight'], dtype='object')

# %%
X=df[['month', 'year', 'brandname', 'productname', 'name']]
y=df[['weight']]

# %%
X
# Out:
#        month  year       brandname     productname              name
# 0          8  2020   Mahavir Steel           Angle         25*25*3mm
# 1          8  2020      TATA Pipes  G.I. Pipe(Mtr)   100_5.4_C Class
# 2          8  2020    G.D.MALHOTRA            Beam          100*50 L
# 3          8  2020   Mahavir Steel         Channel        75*40 -1.7
# 4          8  2020      Polish Bar      Polish Bar            R 16mm
# ...      ...   ...             ...             ...               ...
# 18876      1  2025         Rolling           Angle         40*40*6mm
# 18877      1  2025      TATA Pipes     Round_Pipes  40_C CLASS_4.0mm
# 18878      1  2025  TATA Structura     Square_Pipe  72*72*2.6_YST210
# 18879      1  2025  TATA Structura     Round_Pipes          20_2.0mm
# 18880      1  2025  TATA Structura     Square_Pipe  20*20*1.2_YST210
#
# [18881 rows x 5 columns]

# %%
y
# Out:
#        weight
# 0        11.0
# 1      1480.0
# 2      1707.3
# 3        34.2
# 4         9.5
# ...       ...
# 18876   525.0
# 18877  4000.0
# 18878  4000.0
# 18879   369.0
# 18880   225.0
#
# [18881 rows x 1 columns]

# %%
mct=make_column_transformer((OneHotEncoder(handle_unknown='ignore'),['brandname', 'productname', 'name']),
                           (StandardScaler(),['month', 'year']),
                            remainder='passthrough')

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-3.0.2-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\users\2002v\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\2002v\anaconda3\lib\site-packages (from xgboost) (1.11.4)
# Downloading xgboost-3.0.2-py3-none-win_amd64.whl (150.0 MB)
#    ---------------------------------------- 0.0/150.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/150.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/150.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/150.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/150.0 MB 435.7 kB/s eta 0:05:45
#    ---------------------------------------- 0.1/150.0 MB 657.6 kB/s eta 0:03:48
#    ---------------------------------------- 0.3/150.0 MB 1.7 MB/s eta 0:01:27
#    ---------------------------------------- 1.1/150.0 MB 4.9 MB/s eta 0:00:31
#     --------------------------------------- 1.9/150.0 MB 7.2 MB/s eta 0:00:21
#     --------------------------------------- 3.1/150.0 MB 10.4 MB/s eta 0:00:15
#    - -------------------------------------- 3.9/150.0 MB 11.3 MB/s eta 0:00:13
#    - -------------------------------------- 4.5/150.0 MB 11.0 MB/s eta 0:00:14
#    - -------------------------------------- 5.1/150.0 MB 11.6 MB/s eta 0:00:13
#    - -------------------------------------- 5.6/150.0 MB 11.2 MB/s eta 0:00:13
#    - -------------------------------------- 6.2/150.0 MB 11.3 MB/s eta 0:00:13
#    - -------------------------------------- 6.8/150.0 MB 11.4 MB/s eta 0:00:13
#    - -------------------------------------- 7.3/150.0 MB 11.6 MB/s eta 0:00:13
150.0 MB 12.8 MB/s eta 0:00:02
#    ---------------------------------- ---- 132.0/150.0 MB 12.8 MB/s eta 0:00:02
#    ---------------------------------- ---- 132.6/150.0 MB 12.8 MB/s eta 0:00:02
#    ---------------------------------- ---- 133.2/150.0 MB 13.1 MB/s eta 0:00:02
#    ---------------------------------- ---- 133.8/150.0 MB 12.8 MB/s eta 0:00:02
#    ---------------------------------- ---- 134.4/150.0 MB 13.1 MB/s eta 0:00:02
#    ----------------------------------- --- 135.0/150.0 MB 12.9 MB/s eta 0:00:02
#    ----------------------------------- --- 135.4/150.0 MB 12.8 MB/s eta 0:00:02
#    ----------------------------------- --- 136.2/150.0 MB 12.8 MB/s eta 0:00:02
#    ----------------------------------- --- 136.6/150.0 MB 13.1 MB/s eta 0:00:02
#    ----------------------------------- --- 137.2/150.0 MB 13.1 MB/s eta 0:00:01
#    ----------------------------------- --- 137.8/150.0 MB 12.8 MB/s eta 0:00:01
#    ------------------------------------ -- 138.4/150.0 MB 12.8 MB/s eta 0:00:01
#    ------------------------------------ -- 139.1/150.0 MB 12.8 MB/s eta 0:00:01
#    ------------------------------------ -- 139.7/150.0 MB 13.1 MB/s eta 0:00:01
#    ------------------------------------ -- 140.3/150.0 MB 13.1 MB/s eta 0:00:01
#    ------------------------------------ -- 140.9/150.0 MB 12.8 MB/s eta 0:00:01
#    ------------------------------------ -- 141.5/150.0 MB 13.1 MB/s eta 0:00:01
#    ------------------------------------ -- 142.1/150.0 MB 12.6 MB/s eta 0:00:01
#    ------------------------------------- - 142.7/150.0 MB 13.1 MB/s eta 0:00:01
#    ------------------------------------- - 143.3/150.0 MB 12.8 MB/s eta 0:00:01
#    ------------------------------------- - 143.9/150.0 MB 12.8 MB/s eta 0:00:01
#    ------------------------------------- - 144.5/150.0 MB 12.8 MB/s eta 0:00:01
#    ------------------------------------- - 145.2/150.0 MB 12.8 MB/s eta 0:00:01
#    ------------------------------------- - 145.7/150.0 MB 12.8 MB/s eta 0:00:01
#    --------------------------------------  146.3/150.0 MB 12.9 MB/s eta 0:00:01
#    --------------------------------------  146.9/150.0 MB 13.1 MB/s eta 0:00:01
#    --------------------------------------  147.5/150.0 MB 13.1 MB/s eta 0:00:01
#    --------------------------------------  148.1/150.0 MB 12.8 MB/s eta 0:00:01
#    --------------------------------------  148.7/150.0 MB 13.1 MB/s eta 0:00:01
#    --------------------------------------  149.4/150.0 MB 12.6 MB/s eta 0:00:01
#    --------------------------------------  150.0/150.0 MB 12.6 MB/s eta 0:00:01
#    --------------------------------------  150.0/150.0 MB 12.6 MB/s eta 0:00:01
#    --------------------------------------  150.0/150.0 MB 12.6 MB/s eta 0:00:01
#    --------------------------------------  150.0/150.0 MB 12.6 MB/s eta 0:00:01
#    --------------------------------------  150.0/150.0 MB 12.6 MB/s eta 0:00:01
#    --------------------------------------- 150.0/150.0 MB 10.2 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-3.0.2

# %%
from xgboost import XGBRegressor
xe = XGBRegressor(n_estimators=100, learning_rate=0.2, max_depth=10, n_jobs=-1, verbosity=0)
pipe=make_pipeline(mct,xe)

# %%
import time
start=time.time()
scores = []

for i in range(101):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=i)
    pipe.set_params(xgbregressor__random_state=i)  # Update random_state inside pipeline
    pipe.fit(X_train, y_train)
    y_pred = pipe.predict(X_test)
    
    y_pred_df = pd.DataFrame(data=y_pred, columns=['result'])
    y_test_df = y_test.reset_index(drop=True)
    result = pd.concat([y_test_df, y_pred_df], axis=1)
    
    score = r2_score(result['weight'], result['result'])
    scores.append(score)

best_score = max(scores)
best_random_state = scores.index(best_score)
print(f"Best R2 score: {best_score:.4f} with random_state = {best_random_state}")
end=time.time()
print(f"Elapsed time: {end - start:.2f} seconds")
# Out:
# Best R2 score: 0.7219 with random_state = 22
# Elapsed time: 52.46 seconds

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=22)
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['brandname', 'productname',
#                                                    'name']),
#                                                  ('standardscaler',
#                                                   StandardScaler(),
#                                                   ['month', 'year'])])),
#                 ('xgbregressor',
#                  XGBRegressor(base_score=None, booster=None, callbacks=None,
#                               colsample_bylevel=None, colsample_byn...
#                               feature_types=None, feature_weights=None,
#                               gamma=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=0.2,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=10, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, multi_strategy=None,
#                               n_estimators=100, n_jobs=-1,
#                               num_parallel_tree=None, ...))])

# %%
df.columns
# Out:
# Index(['month', 'year', 'brandname', 'productname', 'name', 'weight'], dtype='object')

# %%
df
# Out:
#        month  year       brandname     productname              name  weight
# 0          8  2020   Mahavir Steel           Angle         25*25*3mm    11.0
# 1          8  2020      TATA Pipes  G.I. Pipe(Mtr)   100_5.4_C Class  1480.0
# 2          8  2020    G.D.MALHOTRA            Beam          100*50 L  1707.3
# 3          8  2020   Mahavir Steel         Channel        75*40 -1.7    34.2
# 4          8  2020      Polish Bar      Polish Bar            R 16mm     9.5
# ...      ...   ...             ...             ...               ...     ...
# 18876      1  2025         Rolling           Angle         40*40*6mm   525.0
# 18877      1  2025      TATA Pipes     Round_Pipes  40_C CLASS_4.0mm  4000.0
# 18878      1  2025  TATA Structura     Square_Pipe  72*72*2.6_YST210  4000.0
# 18879      1  2025  TATA Structura     Round_Pipes          20_2.0mm   369.0
# 18880      1  2025  TATA Structura     Square_Pipe  20*20*1.2_YST210   225.0
#
# [18881 rows x 6 columns]

# %%
myinput=pd.DataFrame([[8,2020,"Mahavir Steel","Angle",	"25*25*3mm"]],columns=['month', 'year', 'brandname', 'productname', 'name'])
myinput
# Out:
#    month  year      brandname productname       name
# 0      8  2020  Mahavir Steel       Angle  25*25*3mm

# %%
res=pipe.predict(myinput)
result=np.round(res[0])
result
# Out:
# 582.0
